# %% [markdown]
# ## Imports

# %%
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from matplotlib import pyplot as plt

from pathlib import Path
CACHE = str(Path("~/.cache/armory").expanduser())

# %% [markdown]
# ## Load Food101 Dataset From Torchvision into Jatic Dataset

# %%
train = datasets.Food101(
    CACHE,
    split="train",
    transform=transforms.Compose(
        [
            transforms.Resize(size=(512, 512)),
        ]
    ),
    download=True
)
dataloader = DataLoader(train, batch_size=1, num_workers=4)

# %% [markdown]
# ## show random samples from the training dataset

# %%
import charmory.display
charmory.display.show_samples(train, samples=9)
# Out:
# chosen_labels={2, 70, 74, 43, 42, 15, 50, 55, 31}
